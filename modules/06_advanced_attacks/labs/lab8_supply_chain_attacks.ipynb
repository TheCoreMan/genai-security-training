# %% [markdown]
# # Lab 8: Supply Chain Attacks
#
# ## Objectives
# - Understand ML supply chain risks
# - Test malicious model distribution
# - Implement verification methods

# %%
import torch
import hashlib

# %% [markdown]
# ## Part 1: Model Verification

# %%
def verify_model(model_path, expected_hash):
    """Verify model integrity"""
    with open(model_path, 'rb') as f:
        model_hash = hashlib.sha256(f.read()).hexdigest()
    return model_hash == expected_hash

# Example
print('Always verify model checksums before loading')
print('Use trusted sources: HuggingFace, official repos')
# Out:
# Always verify model checksums before loading
# Use trusted sources: HuggingFace, official repos
